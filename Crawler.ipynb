# %% [markdown]
# ### Проект. Анна Запорощенко, Софья Генералова

# %% [markdown]
# ### Предобработка текстов
#
# Вам нужно собрать свой корпус текстов (100 штук не менее 100 слов каждый / 10 000 словоупотреблений). Корпус состоит из текстов одного жанра или тематики (не отрывки одного текста).
#
# Можно делать это вручную или скачивая html-страницы средствами Питона (например, библиотека requests). Затем нужно удалить нетекстовые элементы, разделить корпус на предложения. Не забудьте, что для каждого предложения нужно помнить, из какого источника оно берется.

# %%
# !pip install fake_useragent
# Out:
# Collecting fake_useragent
#   Downloading https://files.pythonhosted.org/packages/d1/79/af647635d6968e2deb57a208d309f6069d31cb138066d7e821e575112a80/fake-useragent-0.1.11.tar.gz
# Building wheels for collected packages: fake-useragent
#   Building wheel for fake-useragent (setup.py) ... done
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-cp36-none-any.whl size=13485 sha256=9b56653bc6810549f781278a699b7834490ec96ec6fa5ccd1e17822b41b446d4
#   Stored in directory: /root/.cache/pip/wheels/5e/63/09/d1dc15179f175357d3f5c00cbffbac37f9e8690d80545143ff
# Successfully built fake-useragent
# Installing collected packages: fake-useragent
# Successfully installed fake-useragent-0.1.11

# %%
import urllib.request
from fake_useragent import UserAgent
import re
import random

# %%
# функция возвращает html код страницы
def get_html_content(url):
    user_agent = UserAgent().chrome
    req = urllib.request.Request(url, headers={'User-Agent':user_agent})
    with urllib.request.urlopen(req) as response:
        html_content = response.read().decode('utf-8')
    return html_content

# %%
# функция возвращает ссылки на новости, собранные на странице
def get_links(html_content, pattern, links):
    l = re.findall(pattern, html_content)
    links.extend(l)
    return links

# %%
# инициализируем список для ссылок
# генерируем номера страниц со ссылками на новости (первая без номера, ее оставим) и достаем ссылки из них
links = []
pages = [t for t in range(2,7)]
pattern = '<a href=\'(.+?)\'><h3 class="news-big"'
for n in pages:
    url = 'https://liveberlin.ru/news/'
    url = url + 'page/' + str(n)
    links = get_links(get_html_content(url), pattern, links)

# %%
# функция убирает нерасшифровавшиеся знаки, рекламу, теги в строке
def clear(line):
    line = line.replace('&nbsp;', ' ')
    line = line.replace('&#8217;', "'")
    line = line.replace('\xa0', ' ')
    line = re.split('<.+?>', line)
    line = ('').join(line)
    line = line.replace(' Реклама в «Живом Берлине» | liveberlin.ad@gmail.com', '')
    line = re.sub('\s+', ' ',line) # убирает повторяющиеся пробельные символы
    return line

# %%
# функция достает из html кода новостной страницы текст новости, ее автора и заголовок
def get_info(html_content):
    text = clear((' ').join(re.findall('<p>.+?</p>', html_content)[:-2]))
    title = clear(('').join(re.findall("<meta property=\'og:type\' content=\'article\' />\n    <meta property=\'og:title\' content=\'(.+?)' />", html_content)))
#     author= re.findall("title=\".+?\" rel=\"author\">(.+?)</a>&nbsp;", html_content)[0]
    return text, title #, author

# %%
texts = []
titles = []
# authors = []

# %%
for link in links:
    html_content = get_html_content(link)
#     text, title, author 
    text, title = get_info(html_content)
    texts.append(text)
    titles.append(title + '\n' + link)
#     authors.append(author)

# %%
titles
# Out:
# ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat
#  'Deutsche Telekom сможет ограничивать работу других интернет-провайдеров и даже полностью отключать их\nhttps://liveberlin.ru/news/2019/01/23/deutsche-telekom-smozhet-ogranichivat-rabotu-drugih-internet-provajderov-i-dazhe-polnostyu-otklyuchat-ih/',
#  'Штат берлинской полиции увеличат до 18 тысяч сотрудников\nhttps://liveberlin.ru/news/2019/01/18/shtat-berlinskoj-politsii-uvelichat-do-18-tysyach-sotrudnikov/',
#  'Профицит федерального бюджета за прошлый год составил более 11 миллиардов евро\nhttps://liveberlin.ru/news/2019/01/16/profitsit-federalnogo-byudzheta-za-proshlyj-god-sostavil-bolee-11-milliardov-evro/',
#  'Зарегистрировать автомобиль онлайн можно будет уже в этом году\nhttps://liveberlin.ru/news/2019/01/15/zaregistrirovat-avtomobil-onlajn-mozhno-budet-uzhe-v-etom-godu/',
#  'Запрет на одноразовую посуду из пластика будет введен до 2021 года\nhttps://liveberlin.ru/news/2019/01/14/zapret-na-odnorazovuyu-posudu-iz-plastika-budet-vveden-do-2021-goda/',
#  'Школьные обеды для берлинских младшеклассников станут бесплатными со следующего учебного года\nhttps://liveberlin.ru/news/2019/01/08/shkolnye-obedy-dlya-berlinskih-mladsheklassnikov-stanut-besplatnymi-so-sleduyuschego-uchebnogo-goda/',
#  'Забастовок на немецких железных дорогах не будет до 2021 года\nhttps://liveberlin.ru/news/2019/01/07/zabastovok-na-nemetskih-zheleznyh-dorogah-ne-budet-do-2021-goda/',
#  '12 новых автоматических радаров установят на улицах Берлина\nhttps://liveberlin.ru/news/2019/01/04/12-novyh-avtomaticheskih-radarov-ustanovyat-na-ulitsah-berlina/',
#  '5,5 миллиардов евро выделены на поддержку детских садов\nhttps://liveberlin.ru/news/2019/01/03/55-milliardov-evro-vydeleny-na-podderzhku-detskih-sadov/',
#  'Суд запретил продажу iPhone 7, 8 и X в Германии\nhttps://liveberlin.ru/news/2018/12/27/sud-zapretil-prodazhu-iphone-7-8-i-x-v-germanii/',
#  'Две тысячи немецких заключенных попали под «рождественскую амнистию»\nhttps://liveberlin.ru/news/2018/12/22/dve-tysyachi-nemetskih-zaklyuchennyh-popali-pod-rozhdestvenskuyu-amnistiyu/']

# %% [markdown]
# ### Морфологический анализ текстов
#
# Здесь можно использовать любой инструмент / библиотеку, которая позволяет проводить морфологический анализ.
# Подумайте, нужно ли вам разрешение морфологической неоднозначности. Хорошо бы сказать об этом в презентации и обосновать выбранное решение.
# Не забудьте, что для запросов тоже понадобится морфологический анализ.

# %% [markdown]
# Natasha делит по предложениям.

# %%
from natasha import (
    Segmenter,
    MorphVocab,
    
    NewsEmbedding,
    NewsMorphTagger,
    Doc
)

# %%
segmenter = Segmenter()

emb = NewsEmbedding()

morph_tagger = NewsMorphTagger(emb)

morph_vocab = MorphVocab()

# %%
next_start = 0
for text, text_meta in zip(texts, titles):
    doc = Doc(text)
    doc.segment(segmenter)
    doc.tag_morph(morph_tagger)
    next_start = sent_a(doc, text_meta, next_start) # след начальный айди предложения

# %% [markdown]
# сделать ф-ю: sent_a(doc, text_meta, start=0)

# %%
def sent_a(doc, text_meta, start=0):
    next_start = 0
    for sent_id, sent in enumerate(doc.sents, start):
        next_start = sent_id
        sent_text = sent.text
#         print(sent_text)
        sentence = []
        for tok in sent.tokens:
            pos = tok.pos
            if pos != 'PUNCT':
                tok.lemmatize(morph_vocab)
                lem = tok.lemma
                tex = tok.text
                sentence.append(tex + '<pos:' + pos + '>' + '<lem:' + lem + '>')
        # ДЕЛИТ НА ЭНГРАММЫ
        sent_n_gramm(sentence, sent_text, sent_id, text_meta)
        
    return next_start+1

# %%
big_dict
# Out:
# {'Партия зеленых предложила': {'sent_id': [0],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Партия зеленых предложила ввести ограничение скорости 130 км/ч на немецких автобанах, с целью сократить количество выхлопных газов.'],
#   'tag_ngr': ['Партия<pos:NOUN><lem:партия> зеленых<pos:ADJ><lem:зеленый> предложила<pos:VERB><lem:предложить>']},
#  'зеленых предложила ввести': {'sent_id': [0],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Партия зеленых предложила ввести ограничение скорости 130 км/ч на немецких автобанах, с целью сократить количество выхлопных газов.'],
#   'tag_ngr': ['зеленых<pos:ADJ><lem:зеленый> предложила<pos:VERB><lem:предложить> ввести<pos:VERB><lem:ввести>']},
#  'предложила ввести ограничение': {'sent_id': [0],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Партия зеленых предложила ввести ограничение скорости 130 км/ч на немецких автобанах, с целью сократить количество выхлопных газов.'],
#   'tag_ngr': ['предложила<pos:VERB><lem:предложить> ввести<pos:VERB><lem:ввести> ограничение<pos:NOUN><lem:ограничение>']},
#  'ввести ограничение скорости': {'sent_id': [0],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Партия зеленых предложила ввести ограничение скорости 130 км/ч на немецких автобанах, с целью сократить количество выхлопных газов.'],
#   'tag_ngr': ['ввести<pos:VERB><lem:ввести> ограничение<pos:NOUN><lem:ограничение> скорости<pos:NOUN><lem:скорость>']},
#  'ограничение скорости 130': {'sent_id': [0],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Партия зеленых предложила ввести ограничение скорости 130 км/ч на немецких автобанах, с целью сократить количество выхлопных газов.'],
#   'tag_ngr': ['ограничение<pos:NOUN><lem:ограничение> скорости<pos:NOUN><lem:скорость> 130<pos:NUM><lem:130>']},
#  'скорости 130 км': {'sent_id': [0],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Партия зеленых предложила ввести ограничение скорости 130 км/ч на немецких автобанах, с целью сократить количество выхлопных газов.'],
#   'tag_ngr': ['скорости<pos:NOUN><lem:скорость> 130<pos:NUM><lem:130> км<pos:NOUN><lem:километр>']},
#  '130 км ч': {'sent_id': [0],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Партия зеленых предложила ввести ограничение скорости 130 км/ч на немецких автобанах, с целью сократить количество выхлопных газов.'],
#   'tag_ngr': ['130<pos:NUM><lem:130> км<pos:NOUN><lem:километр> ч<pos:NOUN><lem:часть>']},
#  'км ч на': {'sent_id': [0],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Партия зеленых предложила ввести ограничение скорости 130 км/ч на немецких автобанах, с целью сократить количество выхлопных газов.'],
#   'tag_ngr': ['км<pos:NOUN><lem:километр> ч<pos:NOUN><lem:часть> на<pos:ADP><lem:на>']},
#  'ч на немецких': {'sent_id': [0],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Партия зеленых предложила ввести ограничение скорости 130 км/ч на немецких автобанах, с целью сократить количество выхлопных газов.'],
#   'tag_ngr': ['ч<pos:NOUN><lem:часть> на<pos:ADP><lem:на> немецких<pos:ADJ><lem:немецкий>']},
#  'на немецких автобанах': {'sent_id': [0],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Партия зеленых предложила ввести ограничение скорости 130 км/ч на немецких автобанах, с целью сократить количество выхлопных газов.'],
#   'tag_ngr': ['на<pos:ADP><lem:на> немецких<pos:ADJ><lem:немецкий> автобанах<pos:NOUN><lem:автобан>']},
#  'немецких автобанах с': {'sent_id': [0],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Партия зеленых предложила ввести ограничение скорости 130 км/ч на немецких автобанах, с целью сократить количество выхлопных газов.'],
#   'tag_ngr': ['немецких<pos:ADJ><lem:немецкий> автобанах<pos:NOUN><lem:автобан> с<pos:ADP><lem:с>']},
#  'автобанах с целью': {'sent_id': [0],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Партия зеленых предложила ввести ограничение скорости 130 км/ч на немецких автобанах, с целью сократить количество выхлопных газов.'],
#   'tag_ngr': ['автобанах<pos:NOUN><lem:автобан> с<pos:ADP><lem:с> целью<pos:NOUN><lem:цель>']},
#  'с целью сократить': {'sent_id': [0],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Партия зеленых предложила ввести ограничение скорости 130 км/ч на немецких автобанах, с целью сократить количество выхлопных газов.'],
#   'tag_ngr': ['с<pos:ADP><lem:с> целью<pos:NOUN><lem:цель> сократить<pos:VERB><lem:сократить>']},
#  'целью сократить количество': {'sent_id': [0],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Партия зеленых предложила ввести ограничение скорости 130 км/ч на немецких автобанах, с целью сократить количество выхлопных газов.'],
#   'tag_ngr': ['целью<pos:NOUN><lem:цель> сократить<pos:VERB><lem:сократить> количество<pos:NOUN><lem:количество>']},
#  'сократить количество выхлопных': {'sent_id': [0],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Партия зеленых предложила ввести ограничение скорости 130 км/ч на немецких автобанах, с целью сократить количество выхлопных газов.'],
#   'tag_ngr': ['сократить<pos:VERB><lem:сократить> количество<pos:NOUN><lem:количество> выхлопных<pos:ADJ><lem:выхлопной>']},
#  'количество выхлопных газов': {'sent_id': [0],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Партия зеленых предложила ввести ограничение скорости 130 км/ч на немецких автобанах, с целью сократить количество выхлопных газов.'],
#   'tag_ngr': ['количество<pos:NOUN><lem:количество> выхлопных<pos:ADJ><lem:выхлопной> газов<pos:NOUN><lem:газ>']},
#  'Эта инициатива стала': {'sent_id': [1],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Эта инициатива стала поводом для дебатов в бундестаге, и в итоге парламентарии 498 голосами «против» и 126 «за» отклонили предложение, сообщает Welt.'],
#   'tag_ngr': ['Эта<pos:DET><lem:этот> инициатива<pos:NOUN><lem:инициатива> стала<pos:VERB><lem:стать>']},
#  'инициатива стала поводом': {'sent_id': [1],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Эта инициатива стала поводом для дебатов в бундестаге, и в итоге парламентарии 498 голосами «против» и 126 «за» отклонили предложение, сообщает Welt.'],
#   'tag_ngr': ['инициатива<pos:NOUN><lem:инициатива> стала<pos:VERB><lem:стать> поводом<pos:NOUN><lem:повод>']},
#  'стала поводом для': {'sent_id': [1],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Эта инициатива стала поводом для дебатов в бундестаге, и в итоге парламентарии 498 голосами «против» и 126 «за» отклонили предложение, сообщает Welt.'],
#   'tag_ngr': ['стала<pos:VERB><lem:стать> поводом<pos:NOUN><lem:повод> для<pos:ADP><lem:для>']},
#  'поводом для дебатов': {'sent_id': [1],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Эта инициатива стала поводом для дебатов в бундестаге, и в итоге парламентарии 498 голосами «против» и 126 «за» отклонили предложение, сообщает Welt.'],
#   'tag_ngr': ['поводом<pos:NOUN><lem:повод> для<pos:ADP><lem:для> дебатов<pos:NOUN><lem:дебаты>']},
#  'для дебатов в': {'sent_id': [1],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Эта инициатива стала поводом для дебатов в бундестаге, и в итоге парламентарии 498 голосами «против» и 126 «за» отклонили предложение, сообщает Welt.'],
#   'tag_ngr': ['для<pos:ADP><lem:для> дебатов<pos:NOUN><lem:дебаты> в<pos:ADP><lem:в>']},
#  'дебатов в бундестаге': {'sent_id': [1],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Эта инициатива стала поводом для дебатов в бундестаге, и в итоге парламентарии 498 голосами «против» и 126 «за» отклонили предложение, сообщает Welt.'],
#   'tag_ngr': ['дебатов<pos:NOUN><lem:дебаты> в<pos:ADP><lem:в> бундестаге<pos:NOUN><lem:бундестаг>']},
#  'в бундестаге и': {'sent_id': [1],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Эта инициатива стала поводом для дебатов в бундестаге, и в итоге парламентарии 498 голосами «против» и 126 «за» отклонили предложение, сообщает Welt.'],
#   'tag_ngr': ['в<pos:ADP><lem:в> бундестаге<pos:NOUN><lem:бундестаг> и<pos:CCONJ><lem:и>']},
#  'бундестаге и в': {'sent_id': [1],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Эта инициатива стала поводом для дебатов в бундестаге, и в итоге парламентарии 498 голосами «против» и 126 «за» отклонили предложение, сообщает Welt.'],
#   'tag_ngr': ['бундестаге<pos:NOUN><lem:бундестаг> и<pos:CCONJ><lem:и> в<pos:ADP><lem:в>']},
#  'и в итоге': {'sent_id': [1],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Эта инициатива стала поводом для дебатов в бундестаге, и в итоге парламентарии 498 голосами «против» и 126 «за» отклонили предложение, сообщает Welt.'],
#   'tag_ngr': ['и<pos:CCONJ><lem:и> в<pos:ADP><lem:в> итоге<pos:NOUN><lem:итог>']},
#  'в итоге парламентарии': {'sent_id': [1],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Эта инициатива стала поводом для дебатов в бундестаге, и в итоге парламентарии 498 голосами «против» и 126 «за» отклонили предложение, сообщает Welt.'],
#   'tag_ngr': ['в<pos:ADP><lem:в> итоге<pos:NOUN><lem:итог> парламентарии<pos:NOUN><lem:парламентарий>']},
#  'итоге парламентарии 498': {'sent_id': [1],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Эта инициатива стала поводом для дебатов в бундестаге, и в итоге парламентарии 498 голосами «против» и 126 «за» отклонили предложение, сообщает Welt.'],
#   'tag_ngr': ['итоге<pos:NOUN><lem:итог> парламентарии<pos:NOUN><lem:парламентарий> 498<pos:NUM><lem:498>']},
#  'парламентарии 498 голосами': {'sent_id': [1],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Эта инициатива стала поводом для дебатов в бундестаге, и в итоге парламентарии 498 голосами «против» и 126 «за» отклонили предложение, сообщает Welt.'],
#   'tag_ngr': ['парламентарии<pos:NOUN><lem:парламентарий> 498<pos:NUM><lem:498> голосами<pos:NOUN><lem:голос>']},
#  '498 голосами против': {'sent_id': [1],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Эта инициатива стала поводом для дебатов в бундестаге, и в итоге парламентарии 498 голосами «против» и 126 «за» отклонили предложение, сообщает Welt.'],
#   'tag_ngr': ['498<pos:NUM><lem:498> голосами<pos:NOUN><lem:голос> против<pos:ADV><lem:против>']},
#  'голосами против и': {'sent_id': [1],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Эта инициатива стала поводом для дебатов в бундестаге, и в итоге парламентарии 498 голосами «против» и 126 «за» отклонили предложение, сообщает Welt.'],
#   'tag_ngr': ['голосами<pos:NOUN><lem:голос> против<pos:ADV><lem:против> и<pos:CCONJ><lem:и>']},
#  'против и 126': {'sent_id': [1],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Эта инициатива стала поводом для дебатов в бундестаге, и в итоге парламентарии 498 голосами «против» и 126 «за» отклонили предложение, сообщает Welt.'],
#   'tag_ngr': ['против<pos:ADV><lem:против> и<pos:CCONJ><lem:и> 126<pos:NUM><lem:126>']},
#  'и 126 за': {'sent_id': [1],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Эта инициатива стала поводом для дебатов в бундестаге, и в итоге парламентарии 498 голосами «против» и 126 «за» отклонили предложение, сообщает Welt.'],
#   'tag_ngr': ['и<pos:CCONJ><lem:и> 126<pos:NUM><lem:126> за<pos:ADP><lem:за>']},
#  '126 за отклонили': {'sent_id': [1],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Эта инициатива стала поводом для дебатов в бундестаге, и в итоге парламентарии 498 голосами «против» и 126 «за» отклонили предложение, сообщает Welt.'],
#   'tag_ngr': ['126<pos:NUM><lem:126> за<pos:ADP><lem:за> отклонили<pos:VERB><lem:отклонить>']},
#  'за отклонили предложение': {'sent_id': [1],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Эта инициатива стала поводом для дебатов в бундестаге, и в итоге парламентарии 498 голосами «против» и 126 «за» отклонили предложение, сообщает Welt.'],
#   'tag_ngr': ['за<pos:ADP><lem:за> отклонили<pos:VERB><lem:отклонить> предложение<pos:NOUN><lem:предложение>']},
#  'отклонили предложение сообщает': {'sent_id': [1],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Эта инициатива стала поводом для дебатов в бундестаге, и в итоге парламентарии 498 голосами «против» и 126 «за» отклонили предложение, сообщает Welt.'],
#   'tag_ngr': ['отклонили<pos:VERB><lem:отклонить> предложение<pos:NOUN><lem:предложение> сообщает<pos:VERB><lem:сообщать>']},
#  'предложение сообщает Welt': {'sent_id': [1],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Эта инициатива стала поводом для дебатов в бундестаге, и в итоге парламентарии 498 голосами «против» и 126 «за» отклонили предложение, сообщает Welt.'],
#   'tag_ngr': ['предложение<pos:NOUN><lem:предложение> сообщает<pos:VERB><lem:сообщать> Welt<pos:PROPN><lem:welt>']},
#  'Противники инициативы сочли': {'sent_id': [2],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Противники инициативы сочли это «кампанией против автомобилистов».'],
#   'tag_ngr': ['Противники<pos:NOUN><lem:противник> инициативы<pos:NOUN><lem:инициатива> сочли<pos:VERB><lem:счесть>']},
#  'инициативы сочли это': {'sent_id': [2],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Противники инициативы сочли это «кампанией против автомобилистов».'],
#   'tag_ngr': ['инициативы<pos:NOUN><lem:инициатива> сочли<pos:VERB><lem:счесть> это<pos:PRON><lem:это>']},
#  'сочли это кампанией': {'sent_id': [2],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Противники инициативы сочли это «кампанией против автомобилистов».'],
#   'tag_ngr': ['сочли<pos:VERB><lem:счесть> это<pos:PRON><lem:это> кампанией<pos:NOUN><lem:кампания>']},
#  'это кампанией против': {'sent_id': [2],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Противники инициативы сочли это «кампанией против автомобилистов».'],
#   'tag_ngr': ['это<pos:PRON><lem:это> кампанией<pos:NOUN><lem:кампания> против<pos:ADP><lem:против>']},
#  'кампанией против автомобилистов': {'sent_id': [2],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Противники инициативы сочли это «кампанией против автомобилистов».'],
#   'tag_ngr': ['кампанией<pos:NOUN><lem:кампания> против<pos:ADP><lem:против> автомобилистов<pos:NOUN><lem:автомобилист>']},
#  'Кроме того введение': {'sent_id': [3],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Кроме того, введение ограничений скорости повлекло бы за собой чрезмерный контроль за автобанами.'],
#   'tag_ngr': ['Кроме<pos:ADP><lem:кроме> того<pos:PRON><lem:тот> введение<pos:NOUN><lem:введение>']},
#  'того введение ограничений': {'sent_id': [3],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Кроме того, введение ограничений скорости повлекло бы за собой чрезмерный контроль за автобанами.'],
#   'tag_ngr': ['того<pos:PRON><lem:тот> введение<pos:NOUN><lem:введение> ограничений<pos:NOUN><lem:ограничение>']},
#  'введение ограничений скорости': {'sent_id': [3],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Кроме того, введение ограничений скорости повлекло бы за собой чрезмерный контроль за автобанами.'],
#   'tag_ngr': ['введение<pos:NOUN><lem:введение> ограничений<pos:NOUN><lem:ограничение> скорости<pos:NOUN><lem:скорость>']},
#  'ограничений скорости повлекло': {'sent_id': [3],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Кроме того, введение ограничений скорости повлекло бы за собой чрезмерный контроль за автобанами.'],
#   'tag_ngr': ['ограничений<pos:NOUN><lem:ограничение> скорости<pos:NOUN><lem:скорость> повлекло<pos:VERB><lem:повлечь>']},
#  'скорости повлекло бы': {'sent_id': [3],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Кроме того, введение ограничений скорости повлекло бы за собой чрезмерный контроль за автобанами.'],
#   'tag_ngr': ['скорости<pos:NOUN><lem:скорость> повлекло<pos:VERB><lem:повлечь> бы<pos:AUX><lem:бы>']},
#  'повлекло бы за': {'sent_id': [3],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Кроме того, введение ограничений скорости повлекло бы за собой чрезмерный контроль за автобанами.'],
#   'tag_ngr': ['повлекло<pos:VERB><lem:повлечь> бы<pos:AUX><lem:бы> за<pos:ADP><lem:за>']},
#  'бы за собой': {'sent_id': [3],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Кроме того, введение ограничений скорости повлекло бы за собой чрезмерный контроль за автобанами.'],
#   'tag_ngr': ['бы<pos:AUX><lem:бы> за<pos:ADP><lem:за> собой<pos:PRON><lem:себя>']},
#  'за собой чрезмерный': {'sent_id': [3],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Кроме того, введение ограничений скорости повлекло бы за собой чрезмерный контроль за автобанами.'],
#   'tag_ngr': ['за<pos:ADP><lem:за> собой<pos:PRON><lem:себя> чрезмерный<pos:ADJ><lem:чрезмерный>']},
#  'собой чрезмерный контроль': {'sent_id': [3],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Кроме того, введение ограничений скорости повлекло бы за собой чрезмерный контроль за автобанами.'],
#   'tag_ngr': ['собой<pos:PRON><lem:себя> чрезмерный<pos:ADJ><lem:чрезмерный> контроль<pos:NOUN><lem:контроль>']},
#  'чрезмерный контроль за': {'sent_id': [3],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Кроме того, введение ограничений скорости повлекло бы за собой чрезмерный контроль за автобанами.'],
#   'tag_ngr': ['чрезмерный<pos:ADJ><lem:чрезмерный> контроль<pos:NOUN><lem:контроль> за<pos:ADP><lem:за>']},
#  'контроль за автобанами': {'sent_id': [3],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Кроме того, введение ограничений скорости повлекло бы за собой чрезмерный контроль за автобанами.'],
#   'tag_ngr': ['контроль<pos:NOUN><lem:контроль> за<pos:ADP><lem:за> автобанами<pos:NOUN><lem:автобан>']},
#  'Сторонники же считают': {'sent_id': [4],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Сторонники же считают, что ограничения скорости не только помогут улучшить климатическую ситуацию, но и позволят сократить количество аварий и жертв ДТП.'],
#   'tag_ngr': ['Сторонники<pos:NOUN><lem:сторонник> же<pos:PART><lem:же> считают<pos:VERB><lem:считать>']},
#  'же считают что': {'sent_id': [4],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Сторонники же считают, что ограничения скорости не только помогут улучшить климатическую ситуацию, но и позволят сократить количество аварий и жертв ДТП.'],
#   'tag_ngr': ['же<pos:PART><lem:же> считают<pos:VERB><lem:считать> что<pos:SCONJ><lem:что>']},
#  'считают что ограничения': {'sent_id': [4],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Сторонники же считают, что ограничения скорости не только помогут улучшить климатическую ситуацию, но и позволят сократить количество аварий и жертв ДТП.'],
#   'tag_ngr': ['считают<pos:VERB><lem:считать> что<pos:SCONJ><lem:что> ограничения<pos:NOUN><lem:ограничение>']},
#  'что ограничения скорости': {'sent_id': [4],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Сторонники же считают, что ограничения скорости не только помогут улучшить климатическую ситуацию, но и позволят сократить количество аварий и жертв ДТП.'],
#   'tag_ngr': ['что<pos:SCONJ><lem:что> ограничения<pos:NOUN><lem:ограничение> скорости<pos:NOUN><lem:скорость>']},
#  'ограничения скорости не': {'sent_id': [4],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Сторонники же считают, что ограничения скорости не только помогут улучшить климатическую ситуацию, но и позволят сократить количество аварий и жертв ДТП.'],
#   'tag_ngr': ['ограничения<pos:NOUN><lem:ограничение> скорости<pos:NOUN><lem:скорость> не<pos:PART><lem:не>']},
#  'скорости не только': {'sent_id': [4],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Сторонники же считают, что ограничения скорости не только помогут улучшить климатическую ситуацию, но и позволят сократить количество аварий и жертв ДТП.'],
#   'tag_ngr': ['скорости<pos:NOUN><lem:скорость> не<pos:PART><lem:не> только<pos:PART><lem:только>']},
#  'не только помогут': {'sent_id': [4],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Сторонники же считают, что ограничения скорости не только помогут улучшить климатическую ситуацию, но и позволят сократить количество аварий и жертв ДТП.'],
#   'tag_ngr': ['не<pos:PART><lem:не> только<pos:PART><lem:только> помогут<pos:VERB><lem:помочь>']},
#  'только помогут улучшить': {'sent_id': [4],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Сторонники же считают, что ограничения скорости не только помогут улучшить климатическую ситуацию, но и позволят сократить количество аварий и жертв ДТП.'],
#   'tag_ngr': ['только<pos:PART><lem:только> помогут<pos:VERB><lem:помочь> улучшить<pos:VERB><lem:улучшить>']},
#  'помогут улучшить климатическую': {'sent_id': [4],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Сторонники же считают, что ограничения скорости не только помогут улучшить климатическую ситуацию, но и позволят сократить количество аварий и жертв ДТП.'],
#   'tag_ngr': ['помогут<pos:VERB><lem:помочь> улучшить<pos:VERB><lem:улучшить> климатическую<pos:ADJ><lem:климатический>']},
#  'улучшить климатическую ситуацию': {'sent_id': [4],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Сторонники же считают, что ограничения скорости не только помогут улучшить климатическую ситуацию, но и позволят сократить количество аварий и жертв ДТП.'],
#   'tag_ngr': ['улучшить<pos:VERB><lem:улучшить> климатическую<pos:ADJ><lem:климатический> ситуацию<pos:NOUN><lem:ситуация>']},
#  'климатическую ситуацию но': {'sent_id': [4],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Сторонники же считают, что ограничения скорости не только помогут улучшить климатическую ситуацию, но и позволят сократить количество аварий и жертв ДТП.'],
#   'tag_ngr': ['климатическую<pos:ADJ><lem:климатический> ситуацию<pos:NOUN><lem:ситуация> но<pos:CCONJ><lem:но>']},
#  'ситуацию но и': {'sent_id': [4],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Сторонники же считают, что ограничения скорости не только помогут улучшить климатическую ситуацию, но и позволят сократить количество аварий и жертв ДТП.'],
#   'tag_ngr': ['ситуацию<pos:NOUN><lem:ситуация> но<pos:CCONJ><lem:но> и<pos:CCONJ><lem:и>']},
#  'но и позволят': {'sent_id': [4],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Сторонники же считают, что ограничения скорости не только помогут улучшить климатическую ситуацию, но и позволят сократить количество аварий и жертв ДТП.'],
#   'tag_ngr': ['но<pos:CCONJ><lem:но> и<pos:CCONJ><lem:и> позволят<pos:VERB><lem:позволить>']},
#  'и позволят сократить': {'sent_id': [4],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Сторонники же считают, что ограничения скорости не только помогут улучшить климатическую ситуацию, но и позволят сократить количество аварий и жертв ДТП.'],
#   'tag_ngr': ['и<pos:CCONJ><lem:и> позволят<pos:VERB><lem:позволить> сократить<pos:VERB><lem:сократить>']},
#  'позволят сократить количество': {'sent_id': [4],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Сторонники же считают, что ограничения скорости не только помогут улучшить климатическую ситуацию, но и позволят сократить количество аварий и жертв ДТП.'],
#   'tag_ngr': ['позволят<pos:VERB><lem:позволить> сократить<pos:VERB><lem:сократить> количество<pos:NOUN><lem:количество>']},
#  'сократить количество аварий': {'sent_id': [4],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Сторонники же считают, что ограничения скорости не только помогут улучшить климатическую ситуацию, но и позволят сократить количество аварий и жертв ДТП.'],
#   'tag_ngr': ['сократить<pos:VERB><lem:сократить> количество<pos:NOUN><lem:количество> аварий<pos:NOUN><lem:авария>']},
#  'количество аварий и': {'sent_id': [4],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Сторонники же считают, что ограничения скорости не только помогут улучшить климатическую ситуацию, но и позволят сократить количество аварий и жертв ДТП.'],
#   'tag_ngr': ['количество<pos:NOUN><lem:количество> аварий<pos:NOUN><lem:авария> и<pos:CCONJ><lem:и>']},
#  'аварий и жертв': {'sent_id': [4],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Сторонники же считают, что ограничения скорости не только помогут улучшить климатическую ситуацию, но и позволят сократить количество аварий и жертв ДТП.'],
#   'tag_ngr': ['аварий<pos:NOUN><lem:авария> и<pos:CCONJ><lem:и> жертв<pos:NOUN><lem:жертва>']},
#  'и жертв ДТП': {'sent_id': [4],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Сторонники же считают, что ограничения скорости не только помогут улучшить климатическую ситуацию, но и позволят сократить количество аварий и жертв ДТП.'],
#   'tag_ngr': ['и<pos:CCONJ><lem:и> жертв<pos:NOUN><lem:жертва> ДТП<pos:NOUN><lem:дтп>']},
#  'Отметим что Германия': {'sent_id': [5],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Отметим, что Германия — одна из немногих стран, где нет верхнего ограничения скорости на автомагистралях.'],
#   'tag_ngr': ['Отметим<pos:VERB><lem:отметить> что<pos:SCONJ><lem:что> Германия<pos:PROPN><lem:германия>']},
#  'что Германия одна': {'sent_id': [5],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Отметим, что Германия — одна из немногих стран, где нет верхнего ограничения скорости на автомагистралях.'],
#   'tag_ngr': ['что<pos:SCONJ><lem:что> Германия<pos:PROPN><lem:германия> одна<pos:NUM><lem:один>']},
#  'Германия одна из': {'sent_id': [5],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Отметим, что Германия — одна из немногих стран, где нет верхнего ограничения скорости на автомагистралях.'],
#   'tag_ngr': ['Германия<pos:PROPN><lem:германия> одна<pos:NUM><lem:один> из<pos:ADP><lem:из>']},
#  'одна из немногих': {'sent_id': [5],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Отметим, что Германия — одна из немногих стран, где нет верхнего ограничения скорости на автомагистралях.'],
#   'tag_ngr': ['одна<pos:NUM><lem:один> из<pos:ADP><lem:из> немногих<pos:NUM><lem:немногий>']},
#  'из немногих стран': {'sent_id': [5],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Отметим, что Германия — одна из немногих стран, где нет верхнего ограничения скорости на автомагистралях.'],
#   'tag_ngr': ['из<pos:ADP><lem:из> немногих<pos:NUM><lem:немногий> стран<pos:NOUN><lem:страна>']},
#  'немногих стран где': {'sent_id': [5],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Отметим, что Германия — одна из немногих стран, где нет верхнего ограничения скорости на автомагистралях.'],
#   'tag_ngr': ['немногих<pos:NUM><lem:немногий> стран<pos:NOUN><lem:страна> где<pos:ADV><lem:где>']},
#  'стран где нет': {'sent_id': [5],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Отметим, что Германия — одна из немногих стран, где нет верхнего ограничения скорости на автомагистралях.'],
#   'tag_ngr': ['стран<pos:NOUN><lem:страна> где<pos:ADV><lem:где> нет<pos:VERB><lem:нет>']},
#  'где нет верхнего': {'sent_id': [5],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Отметим, что Германия — одна из немногих стран, где нет верхнего ограничения скорости на автомагистралях.'],
#   'tag_ngr': ['где<pos:ADV><lem:где> нет<pos:VERB><lem:нет> верхнего<pos:ADJ><lem:верхний>']},
#  'нет верхнего ограничения': {'sent_id': [5],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Отметим, что Германия — одна из немногих стран, где нет верхнего ограничения скорости на автомагистралях.'],
#   'tag_ngr': ['нет<pos:VERB><lem:нет> верхнего<pos:ADJ><lem:верхний> ограничения<pos:NOUN><lem:ограничение>']},
#  'верхнего ограничения скорости': {'sent_id': [5],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Отметим, что Германия — одна из немногих стран, где нет верхнего ограничения скорости на автомагистралях.'],
#   'tag_ngr': ['верхнего<pos:ADJ><lem:верхний> ограничения<pos:NOUN><lem:ограничение> скорости<pos:NOUN><lem:скорость>']},
#  'ограничения скорости на': {'sent_id': [5],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Отметим, что Германия — одна из немногих стран, где нет верхнего ограничения скорости на автомагистралях.'],
#   'tag_ngr': ['ограничения<pos:NOUN><lem:ограничение> скорости<pos:NOUN><lem:скорость> на<pos:ADP><lem:на>']},
#  'скорости на автомагистралях': {'sent_id': [5],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['Отметим, что Германия — одна из немногих стран, где нет верхнего ограничения скорости на автомагистралях.'],
#   'tag_ngr': ['скорости<pos:NOUN><lem:скорость> на<pos:ADP><lem:на> автомагистралях<pos:NOUN><lem:автомагистраль>']},
#  'И в частности': {'sent_id': [6],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['И, в частности, эта ее особенность является одним из резонов для автотуристов из соседних государств чаще заезжать на «скорость-френдли» автобаны страны.'],
#   'tag_ngr': ['И<pos:CCONJ><lem:и> в<pos:ADP><lem:в> частности<pos:NOUN><lem:частность>']},
#  'в частности эта': {'sent_id': [6],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['И, в частности, эта ее особенность является одним из резонов для автотуристов из соседних государств чаще заезжать на «скорость-френдли» автобаны страны.'],
#   'tag_ngr': ['в<pos:ADP><lem:в> частности<pos:NOUN><lem:частность> эта<pos:DET><lem:этот>']},
#  'частности эта ее': {'sent_id': [6],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['И, в частности, эта ее особенность является одним из резонов для автотуристов из соседних государств чаще заезжать на «скорость-френдли» автобаны страны.'],
#   'tag_ngr': ['частности<pos:NOUN><lem:частность> эта<pos:DET><lem:этот> ее<pos:DET><lem:ее>']},
#  'эта ее особенность': {'sent_id': [6],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['И, в частности, эта ее особенность является одним из резонов для автотуристов из соседних государств чаще заезжать на «скорость-френдли» автобаны страны.'],
#   'tag_ngr': ['эта<pos:DET><lem:этот> ее<pos:DET><lem:ее> особенность<pos:NOUN><lem:особенность>']},
#  'ее особенность является': {'sent_id': [6],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['И, в частности, эта ее особенность является одним из резонов для автотуристов из соседних государств чаще заезжать на «скорость-френдли» автобаны страны.'],
#   'tag_ngr': ['ее<pos:DET><lem:ее> особенность<pos:NOUN><lem:особенность> является<pos:VERB><lem:являться>']},
#  'особенность является одним': {'sent_id': [6],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['И, в частности, эта ее особенность является одним из резонов для автотуристов из соседних государств чаще заезжать на «скорость-френдли» автобаны страны.'],
#   'tag_ngr': ['особенность<pos:NOUN><lem:особенность> является<pos:VERB><lem:являться> одним<pos:NUM><lem:один>']},
#  'является одним из': {'sent_id': [6],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['И, в частности, эта ее особенность является одним из резонов для автотуристов из соседних государств чаще заезжать на «скорость-френдли» автобаны страны.'],
#   'tag_ngr': ['является<pos:VERB><lem:являться> одним<pos:NUM><lem:один> из<pos:ADP><lem:из>']},
#  'одним из резонов': {'sent_id': [6],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['И, в частности, эта ее особенность является одним из резонов для автотуристов из соседних государств чаще заезжать на «скорость-френдли» автобаны страны.'],
#   'tag_ngr': ['одним<pos:NUM><lem:один> из<pos:ADP><lem:из> резонов<pos:NOUN><lem:резон>']},
#  'из резонов для': {'sent_id': [6],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['И, в частности, эта ее особенность является одним из резонов для автотуристов из соседних государств чаще заезжать на «скорость-френдли» автобаны страны.'],
#   'tag_ngr': ['из<pos:ADP><lem:из> резонов<pos:NOUN><lem:резон> для<pos:ADP><lem:для>']},
#  'резонов для автотуристов': {'sent_id': [6],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['И, в частности, эта ее особенность является одним из резонов для автотуристов из соседних государств чаще заезжать на «скорость-френдли» автобаны страны.'],
#   'tag_ngr': ['резонов<pos:NOUN><lem:резон> для<pos:ADP><lem:для> автотуристов<pos:NOUN><lem:автотурист>']},
#  'для автотуристов из': {'sent_id': [6],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['И, в частности, эта ее особенность является одним из резонов для автотуристов из соседних государств чаще заезжать на «скорость-френдли» автобаны страны.'],
#   'tag_ngr': ['для<pos:ADP><lem:для> автотуристов<pos:NOUN><lem:автотурист> из<pos:ADP><lem:из>']},
#  'автотуристов из соседних': {'sent_id': [6],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['И, в частности, эта ее особенность является одним из резонов для автотуристов из соседних государств чаще заезжать на «скорость-френдли» автобаны страны.'],
#   'tag_ngr': ['автотуристов<pos:NOUN><lem:автотурист> из<pos:ADP><lem:из> соседних<pos:ADJ><lem:соседний>']},
#  'из соседних государств': {'sent_id': [6],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['И, в частности, эта ее особенность является одним из резонов для автотуристов из соседних государств чаще заезжать на «скорость-френдли» автобаны страны.'],
#   'tag_ngr': ['из<pos:ADP><lem:из> соседних<pos:ADJ><lem:соседний> государств<pos:NOUN><lem:государство>']},
#  'соседних государств чаще': {'sent_id': [6],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['И, в частности, эта ее особенность является одним из резонов для автотуристов из соседних государств чаще заезжать на «скорость-френдли» автобаны страны.'],
#   'tag_ngr': ['соседних<pos:ADJ><lem:соседний> государств<pos:NOUN><lem:государство> чаще<pos:ADV><lem:частый>']},
#  'государств чаще заезжать': {'sent_id': [6],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['И, в частности, эта ее особенность является одним из резонов для автотуристов из соседних государств чаще заезжать на «скорость-френдли» автобаны страны.'],
#   'tag_ngr': ['государств<pos:NOUN><lem:государство> чаще<pos:ADV><lem:частый> заезжать<pos:VERB><lem:заезжать>']},
#  'чаще заезжать на': {'sent_id': [6],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['И, в частности, эта ее особенность является одним из резонов для автотуристов из соседних государств чаще заезжать на «скорость-френдли» автобаны страны.'],
#   'tag_ngr': ['чаще<pos:ADV><lem:частый> заезжать<pos:VERB><lem:заезжать> на<pos:ADP><lem:на>']},
#  'заезжать на скорость-френдли': {'sent_id': [6],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['И, в частности, эта ее особенность является одним из резонов для автотуристов из соседних государств чаще заезжать на «скорость-френдли» автобаны страны.'],
#   'tag_ngr': ['заезжать<pos:VERB><lem:заезжать> на<pos:ADP><lem:на> скорость-френдли<pos:NOUN><lem:скорость-френдли>']},
#  'на скорость-френдли автобаны': {'sent_id': [6],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
#   'sent_text': ['И, в частности, эта ее особенность является одним из резонов для автотуристов из соседних государств чаще заезжать на «скорость-френдли» автобаны страны.'],
#   'tag_ngr': ['на<pos:ADP><lem:на> скорость-френдли<pos:NOUN><lem:скорость-френдли> автобаны<pos:VERB><lem:автобан>']},
#  'скорость-френдли автобаны страны': {'sent_id': [6],
#   'text_meta': ['Ограничениям скорости на немецких автобанах не бывать!\nhttps://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/'],
# ...
#    'Отныне зарабатывающие от 450,01 до 1300 евро в месяц будут считаться занятыми на так называемой Midijob.',
#    'Профсоюз работников сферы услуг Verdi и правительства всех федеральных земель, за исключением Гессена, пришли на прошлой неделе к соглашению, что заработные платы всех госслужащих будут поэтапно подняты почти на 8%, но не менее, чем на 240 евро в месяц.',
#    'Например, младший медицинский персонал (Pflegekräfte) может рассчитывать на дополнительные 120 евро в месяц, а стажеры (Auszubildende) — на 50 евро.',
#    'Нововведения предусматривают выплаты 130 и 390 евро в месяц и квартал.',
#    'Семьи с низким доходом или получающие социальное пособие платят меньше — 20 евро в месяц.'],
#   'tag_ngr': ['евро<pos:NOUN><lem:евро> в<pos:ADP><lem:в> месяц<pos:NOUN><lem:месяц>',
#    'евро<pos:NOUN><lem:евро> в<pos:ADP><lem:в> месяц<pos:NOUN><lem:месяц>',
#    'евро<pos:NOUN><lem:евро> в<pos:ADP><lem:в> месяц<pos:NOUN><lem:месяц>',
#    'евро<pos:NOUN><lem:евро> в<pos:ADP><lem:в> месяц<pos:NOUN><lem:месяц>',
#    'евро<pos:NOUN><lem:евро> в<pos:ADP><lem:в> месяц<pos:NOUN><lem:месяц>',
#    'евро<pos:NOUN><lem:евро> в<pos:ADP><lem:в> месяц<pos:NOUN><lem:месяц>',
#    'евро<pos:NOUN><lem:евро> в<pos:ADP><lem:в> месяц<pos:NOUN><lem:месяц>',
#    'евро<pos:NOUN><lem:евро> в<pos:ADP><lem:в> месяц<pos:NOUN><lem:месяц>',
#    'евро<pos:NOUN><lem:евро> в<pos:ADP><lem:в> месяц<pos:NOUN><lem:месяц>',
#    'евро<pos:NOUN><lem:евро> в<pos:ADP><lem:в> месяц<pos:NOUN><lem:месяц>',
#    'евро<pos:NOUN><lem:евро> в<pos:ADP><lem:в> месяц<pos:NOUN><lem:месяц>',
#    'евро<pos:NOUN><lem:евро> в<pos:ADP><lem:в> месяц<pos:NOUN><lem:месяц>']},
#  'в месяц и': {'sent_id': [60, 787],
#   'text_meta': ['Доконтактная профилактика ВИЧ (PrEP) теперь оплачивается больничными кассами\nhttps://liveberlin.ru/news/2019/09/16/dokontaktnaya-profilaktika-vich-prep-teper-oplachivaetsya-bolnichnymi-kassami/',
#    'Государственные студенческие стипендии (BAföG) планируют увеличить со следующего учебного года\nhttps://liveberlin.ru/news/2019/02/14/gosudarstvennye-studencheskie-stipendii-bafog-planiruyut-uvelichit-so-sleduyuschego-uchebnogo-goda/'],
#   'sent_text': ['Новое правило позволит людям группы риска экономить на покупке препаратов около 40 евро в месяц и, согласно аналогичному опыту Австралии, снизить число заражений ВИЧ.',
#    'Нововведения предусматривают выплаты 130 и 390 евро в месяц и квартал.'],
#   'tag_ngr': ['в<pos:ADP><lem:в> месяц<pos:NOUN><lem:месяц> и<pos:CCONJ><lem:и>',
#    'в<pos:ADP><lem:в> месяц<pos:NOUN><lem:месяц> и<pos:CCONJ><lem:и>']},
#  'месяц и согласно': {'sent_id': [60],
#   'text_meta': ['Доконтактная профилактика ВИЧ (PrEP) теперь оплачивается больничными кассами\nhttps://liveberlin.ru/news/2019/09/16/dokontaktnaya-profilaktika-vich-prep-teper-oplachivaetsya-bolnichnymi-kassami/'],
#   'sent_text': ['Новое правило позволит людям группы риска экономить на покупке препаратов около 40 евро в месяц и, согласно аналогичному опыту Австралии, снизить число заражений ВИЧ.'],
#   'tag_ngr': ['месяц<pos:NOUN><lem:месяц> и<pos:CCONJ><lem:и> согласно<pos:ADP><lem:согласно>']},
#  'и согласно аналогичному': {'sent_id': [60],
#   'text_meta': ['Доконтактная профилактика ВИЧ (PrEP) теперь оплачивается больничными кассами\nhttps://liveberlin.ru/news/2019/09/16/dokontaktnaya-profilaktika-vich-prep-teper-oplachivaetsya-bolnichnymi-kassami/'],
#   'sent_text': ['Новое правило позволит людям группы риска экономить на покупке препаратов около 40 евро в месяц и, согласно аналогичному опыту Австралии, снизить число заражений ВИЧ.'],
#   'tag_ngr': ['и<pos:CCONJ><lem:и> согласно<pos:ADP><lem:согласно> аналогичному<pos:ADJ><lem:аналогичный>']},
#  'согласно аналогичному опыту': {'sent_id': [60],
#   'text_meta': ['Доконтактная профилактика ВИЧ (PrEP) теперь оплачивается больничными кассами\nhttps://liveberlin.ru/news/2019/09/16/dokontaktnaya-profilaktika-vich-prep-teper-oplachivaetsya-bolnichnymi-kassami/'],
#   'sent_text': ['Новое правило позволит людям группы риска экономить на покупке препаратов около 40 евро в месяц и, согласно аналогичному опыту Австралии, снизить число заражений ВИЧ.'],
#   'tag_ngr': ['согласно<pos:ADP><lem:согласно> аналогичному<pos:ADJ><lem:аналогичный> опыту<pos:NOUN><lem:опыт>']},
#  'аналогичному опыту Австралии': {'sent_id': [60],
#   'text_meta': ['Доконтактная профилактика ВИЧ (PrEP) теперь оплачивается больничными кассами\nhttps://liveberlin.ru/news/2019/09/16/dokontaktnaya-profilaktika-vich-prep-teper-oplachivaetsya-bolnichnymi-kassami/'],
#   'sent_text': ['Новое правило позволит людям группы риска экономить на покупке препаратов около 40 евро в месяц и, согласно аналогичному опыту Австралии, снизить число заражений ВИЧ.'],
#   'tag_ngr': ['аналогичному<pos:ADJ><lem:аналогичный> опыту<pos:NOUN><lem:опыт> Австралии<pos:PROPN><lem:австралия>']},
#  'опыту Австралии снизить': {'sent_id': [60],
#   'text_meta': ['Доконтактная профилактика ВИЧ (PrEP) теперь оплачивается больничными кассами\nhttps://liveberlin.ru/news/2019/09/16/dokontaktnaya-profilaktika-vich-prep-teper-oplachivaetsya-bolnichnymi-kassami/'],
#   'sent_text': ['Новое правило позволит людям группы риска экономить на покупке препаратов около 40 евро в месяц и, согласно аналогичному опыту Австралии, снизить число заражений ВИЧ.'],
#   'tag_ngr': ['опыту<pos:NOUN><lem:опыт> Австралии<pos:PROPN><lem:австралия> снизить<pos:VERB><lem:снизить>']},
#  'Австралии снизить число': {'sent_id': [60],
#   'text_meta': ['Доконтактная профилактика ВИЧ (PrEP) теперь оплачивается больничными кассами\nhttps://liveberlin.ru/news/2019/09/16/dokontaktnaya-profilaktika-vich-prep-teper-oplachivaetsya-bolnichnymi-kassami/'],
#   'sent_text': ['Новое правило позволит людям группы риска экономить на покупке препаратов около 40 евро в месяц и, согласно аналогичному опыту Австралии, снизить число заражений ВИЧ.'],
#   'tag_ngr': ['Австралии<pos:PROPN><lem:австралия> снизить<pos:VERB><lem:снизить> число<pos:NOUN><lem:число>']},
#  'снизить число заражений': {'sent_id': [60],
#   'text_meta': ['Доконтактная профилактика ВИЧ (PrEP) теперь оплачивается больничными кассами\nhttps://liveberlin.ru/news/2019/09/16/dokontaktnaya-profilaktika-vich-prep-teper-oplachivaetsya-bolnichnymi-kassami/'],
#   'sent_text': ['Новое правило позволит людям группы риска экономить на покупке препаратов около 40 евро в месяц и, согласно аналогичному опыту Австралии, снизить число заражений ВИЧ.'],
#   'tag_ngr': ['снизить<pos:VERB><lem:снизить> число<pos:NOUN><lem:число> заражений<pos:NOUN><lem:заражение>']},
#  'число заражений ВИЧ': {'sent_id': [60],
#   'text_meta': ['Доконтактная профилактика ВИЧ (PrEP) теперь оплачивается больничными кассами\nhttps://liveberlin.ru/news/2019/09/16/dokontaktnaya-profilaktika-vich-prep-teper-oplachivaetsya-bolnichnymi-kassami/'],
#   'sent_text': ['Новое правило позволит людям группы риска экономить на покупке препаратов около 40 евро в месяц и, согласно аналогичному опыту Австралии, снизить число заражений ВИЧ.'],
#   'tag_ngr': ['число<pos:NOUN><lem:число> заражений<pos:NOUN><lem:заражение> ВИЧ<pos:PROPN><lem:вич>']},
#  'Убер сервис вызова': {'sent_id': [61],
#   'text_meta': ['Убер-грузовики выйдут на дороги Германии\nhttps://liveberlin.ru/news/2019/08/29/uber-gruzoviki-vyjdut-na-dorogi-germanii/'],
#   'sent_text': ['Убер, сервис вызова частных водителей и такси, собирается стать посредником еще и в грузовых перевозках.'],
#   'tag_ngr': ['Убер<pos:PROPN><lem:убер> сервис<pos:NOUN><lem:сервис> вызова<pos:NOUN><lem:вызов>']},
#  'сервис вызова частных': {'sent_id': [61],
#   'text_meta': ['Убер-грузовики выйдут на дороги Германии\nhttps://liveberlin.ru/news/2019/08/29/uber-gruzoviki-vyjdut-na-dorogi-germanii/'],
#   'sent_text': ['Убер, сервис вызова частных водителей и такси, собирается стать посредником еще и в грузовых перевозках.'],
#   'tag_ngr': ['сервис<pos:NOUN><lem:сервис> вызова<pos:NOUN><lem:вызов> частных<pos:ADJ><lem:частный>']},
#  'вызова частных водителей': {'sent_id': [61],
#   'text_meta': ['Убер-грузовики выйдут на дороги Германии\nhttps://liveberlin.ru/news/2019/08/29/uber-gruzoviki-vyjdut-na-dorogi-germanii/'],
#   'sent_text': ['Убер, сервис вызова частных водителей и такси, собирается стать посредником еще и в грузовых перевозках.'],
#   'tag_ngr': ['вызова<pos:NOUN><lem:вызов> частных<pos:ADJ><lem:частный> водителей<pos:NOUN><lem:водитель>']},
#  'частных водителей и': {'sent_id': [61],
#   'text_meta': ['Убер-грузовики выйдут на дороги Германии\nhttps://liveberlin.ru/news/2019/08/29/uber-gruzoviki-vyjdut-na-dorogi-germanii/'],
#   'sent_text': ['Убер, сервис вызова частных водителей и такси, собирается стать посредником еще и в грузовых перевозках.'],
#   'tag_ngr': ['частных<pos:ADJ><lem:частный> водителей<pos:NOUN><lem:водитель> и<pos:CCONJ><lem:и>']},
#  'водителей и такси': {'sent_id': [61],
#   'text_meta': ['Убер-грузовики выйдут на дороги Германии\nhttps://liveberlin.ru/news/2019/08/29/uber-gruzoviki-vyjdut-na-dorogi-germanii/'],
#   'sent_text': ['Убер, сервис вызова частных водителей и такси, собирается стать посредником еще и в грузовых перевозках.'],
#   'tag_ngr': ['водителей<pos:NOUN><lem:водитель> и<pos:CCONJ><lem:и> такси<pos:NOUN><lem:такси>']},
#  'и такси собирается': {'sent_id': [61],
#   'text_meta': ['Убер-грузовики выйдут на дороги Германии\nhttps://liveberlin.ru/news/2019/08/29/uber-gruzoviki-vyjdut-na-dorogi-germanii/'],
#   'sent_text': ['Убер, сервис вызова частных водителей и такси, собирается стать посредником еще и в грузовых перевозках.'],
#   'tag_ngr': ['и<pos:CCONJ><lem:и> такси<pos:NOUN><lem:такси> собирается<pos:VERB><lem:собираться>']},
#  'такси собирается стать': {'sent_id': [61],
#   'text_meta': ['Убер-грузовики выйдут на дороги Германии\nhttps://liveberlin.ru/news/2019/08/29/uber-gruzoviki-vyjdut-na-dorogi-germanii/'],
#   'sent_text': ['Убер, сервис вызова частных водителей и такси, собирается стать посредником еще и в грузовых перевозках.'],
#   'tag_ngr': ['такси<pos:NOUN><lem:такси> собирается<pos:VERB><lem:собираться> стать<pos:VERB><lem:стать>']},
#  'собирается стать посредником': {'sent_id': [61],
#   'text_meta': ['Убер-грузовики выйдут на дороги Германии\nhttps://liveberlin.ru/news/2019/08/29/uber-gruzoviki-vyjdut-na-dorogi-germanii/'],
#   'sent_text': ['Убер, сервис вызова частных водителей и такси, собирается стать посредником еще и в грузовых перевозках.'],
#   'tag_ngr': ['собирается<pos:VERB><lem:собираться> стать<pos:VERB><lem:стать> посредником<pos:NOUN><lem:посредник>']},
#  'стать посредником еще': {'sent_id': [61],
#   'text_meta': ['Убер-грузовики выйдут на дороги Германии\nhttps://liveberlin.ru/news/2019/08/29/uber-gruzoviki-vyjdut-na-dorogi-germanii/'],
#   'sent_text': ['Убер, сервис вызова частных водителей и такси, собирается стать посредником еще и в грузовых перевозках.'],
#   'tag_ngr': ['стать<pos:VERB><lem:стать> посредником<pos:NOUN><lem:посредник> еще<pos:ADV><lem:еще>']},
#  'посредником еще и': {'sent_id': [61],
#   'text_meta': ['Убер-грузовики выйдут на дороги Германии\nhttps://liveberlin.ru/news/2019/08/29/uber-gruzoviki-vyjdut-na-dorogi-germanii/'],
#   'sent_text': ['Убер, сервис вызова частных водителей и такси, собирается стать посредником еще и в грузовых перевозках.'],
#   'tag_ngr': ['посредником<pos:NOUN><lem:посредник> еще<pos:ADV><lem:еще> и<pos:PART><lem:и>']},
#  'еще и в': {'sent_id': [61],
#   'text_meta': ['Убер-грузовики выйдут на дороги Германии\nhttps://liveberlin.ru/news/2019/08/29/uber-gruzoviki-vyjdut-na-dorogi-germanii/'],
#   'sent_text': ['Убер, сервис вызова частных водителей и такси, собирается стать посредником еще и в грузовых перевозках.'],
#   'tag_ngr': ['еще<pos:ADV><lem:еще> и<pos:PART><lem:и> в<pos:ADP><lem:в>']},
#  'и в грузовых': {'sent_id': [61],
#   'text_meta': ['Убер-грузовики выйдут на дороги Германии\nhttps://liveberlin.ru/news/2019/08/29/uber-gruzoviki-vyjdut-na-dorogi-germanii/'],
#   'sent_text': ['Убер, сервис вызова частных водителей и такси, собирается стать посредником еще и в грузовых перевозках.'],
#   'tag_ngr': ['и<pos:PART><lem:и> в<pos:ADP><lem:в> грузовых<pos:ADJ><lem:грузовой>']},
#  'в грузовых перевозках': {'sent_id': [61],
#   'text_meta': ['Убер-грузовики выйдут на дороги Германии\nhttps://liveberlin.ru/news/2019/08/29/uber-gruzoviki-vyjdut-na-dorogi-germanii/'],
#   'sent_text': ['Убер, сервис вызова частных водителей и такси, собирается стать посредником еще и в грузовых перевозках.'],
#   'tag_ngr': ['в<pos:ADP><lem:в> грузовых<pos:ADJ><lem:грузовой> перевозках<pos:NOUN><lem:перевозка>']},
#  'Предприятия смогут заказывать': {'sent_id': [62],
#   'text_meta': ['Убер-грузовики выйдут на дороги Германии\nhttps://liveberlin.ru/news/2019/08/29/uber-gruzoviki-vyjdut-na-dorogi-germanii/'],
#   'sent_text': ['Предприятия смогут заказывать перевозку своих товаров и заранее будут знать цену на услугу: стоимость будет высчитывать алгоритм.'],
#   'tag_ngr': ['Предприятия<pos:NOUN><lem:предприятие> смогут<pos:VERB><lem:смочь> заказывать<pos:VERB><lem:заказывать>']},
#  'смогут заказывать перевозку': {'sent_id': [62],
#   'text_meta': ['Убер-грузовики выйдут на дороги Германии\nhttps://liveberlin.ru/news/2019/08/29/uber-gruzoviki-vyjdut-na-dorogi-germanii/'],
#   'sent_text': ['Предприятия смогут заказывать перевозку своих товаров и заранее будут знать цену на услугу: стоимость будет высчитывать алгоритм.'],
#   'tag_ngr': ['смогут<pos:VERB><lem:смочь> заказывать<pos:VERB><lem:заказывать> перевозку<pos:NOUN><lem:перевозка>']},
#  'заказывать перевозку своих': {'sent_id': [62],
#   'text_meta': ['Убер-грузовики выйдут на дороги Германии\nhttps://liveberlin.ru/news/2019/08/29/uber-gruzoviki-vyjdut-na-dorogi-germanii/'],
#   'sent_text': ['Предприятия смогут заказывать перевозку своих товаров и заранее будут знать цену на услугу: стоимость будет высчитывать алгоритм.'],
#   'tag_ngr': ['заказывать<pos:VERB><lem:заказывать> перевозку<pos:NOUN><lem:перевозка> своих<pos:DET><lem:свой>']},
#  'перевозку своих товаров': {'sent_id': [62],
#   'text_meta': ['Убер-грузовики выйдут на дороги Германии\nhttps://liveberlin.ru/news/2019/08/29/uber-gruzoviki-vyjdut-na-dorogi-germanii/'],
#   'sent_text': ['Предприятия смогут заказывать перевозку своих товаров и заранее будут знать цену на услугу: стоимость будет высчитывать алгоритм.'],
#   'tag_ngr': ['перевозку<pos:NOUN><lem:перевозка> своих<pos:DET><lem:свой> товаров<pos:NOUN><lem:товар>']},
#  'своих товаров и': {'sent_id': [62],
#   'text_meta': ['Убер-грузовики выйдут на дороги Германии\nhttps://liveberlin.ru/news/2019/08/29/uber-gruzoviki-vyjdut-na-dorogi-germanii/'],
#   'sent_text': ['Предприятия смогут заказывать перевозку своих товаров и заранее будут знать цену на услугу: стоимость будет высчитывать алгоритм.'],
#   'tag_ngr': ['своих<pos:DET><lem:свой> товаров<pos:NOUN><lem:товар> и<pos:CCONJ><lem:и>']},
#  'товаров и заранее': {'sent_id': [62],
#   'text_meta': ['Убер-грузовики выйдут на дороги Германии\nhttps://liveberlin.ru/news/2019/08/29/uber-gruzoviki-vyjdut-na-dorogi-germanii/'],
#   'sent_text': ['Предприятия смогут заказывать перевозку своих товаров и заранее будут знать цену на услугу: стоимость будет высчитывать алгоритм.'],
#   'tag_ngr': ['товаров<pos:NOUN><lem:товар> и<pos:CCONJ><lem:и> заранее<pos:ADV><lem:заранее>']},
#  'и заранее будут': {'sent_id': [62],
#   'text_meta': ['Убер-грузовики выйдут на дороги Германии\nhttps://liveberlin.ru/news/2019/08/29/uber-gruzoviki-vyjdut-na-dorogi-germanii/'],
#   'sent_text': ['Предприятия смогут заказывать перевозку своих товаров и заранее будут знать цену на услугу: стоимость будет высчитывать алгоритм.'],
#   'tag_ngr': ['и<pos:CCONJ><lem:и> заранее<pos:ADV><lem:заранее> будут<pos:AUX><lem:быть>']},
#  'заранее будут знать': {'sent_id': [62],
#   'text_meta': ['Убер-грузовики выйдут на дороги Германии\nhttps://liveberlin.ru/news/2019/08/29/uber-gruzoviki-vyjdut-na-dorogi-germanii/'],
#   'sent_text': ['Предприятия смогут заказывать перевозку своих товаров и заранее будут знать цену на услугу: стоимость будет высчитывать алгоритм.'],
#   'tag_ngr': ['заранее<pos:ADV><lem:заранее> будут<pos:AUX><lem:быть> знать<pos:VERB><lem:знать>']},
#  ...}

# %% [markdown]
# 13782 3gramm

# %%
big_dict = {}

# %%
def sent_n_gramm(mas_for_sent, sent_text, sent_id, text_meta):
    rr = []
    ln = len(mas_for_sent)
    if ln < 3 and ln > 0:
        rr.append(' '.join(mas_for_sent))
    else:
        for i in range(ln):
            if i < ln-2:
                res = mas_for_sent[i] + ' ' + mas_for_sent[i+1] + ' ' + mas_for_sent[i+2]
                rr.append(res)
                
    for n_gr in rr:
        ws = n_gr.split('> ')
        ngrm = [] # list from which i will concatenate strs
        for w in ws: # для кажд части энграммы
            w_text = re.search('([^<>]+)<', w).group(1)
            ngrm.append(w_text)
    
        ngrm_s = ' '.join(ngrm)
        if ngrm_s not in big_dict:
            big_dict[ngrm_s] = {'sent_id': [], 'text_meta':[], 'sent_text':[], 'tag_ngr':[]}
            
        if sent_id not in big_dict[ngrm_s]['sent_id'] or n_gr not in big_dict[ngrm_s]['tag_ngr']:
            big_dict[ngrm_s]['sent_id'].append(sent_id)
            big_dict[ngrm_s]['text_meta'].append(text_meta)
            big_dict[ngrm_s]['sent_text'].append(sent_text)
            big_dict[ngrm_s]['tag_ngr'].append(n_gr)

# %%
import sqlite3

# %%
#подключаемся к базе данных
conn = sqlite3.connect('project_db.db')

# %%
cur = conn.cursor()

# %% [markdown]
# таблица для предложений

# %%
cur.execute("CREATE TABLE IF NOT EXISTS 'Sentences'('sent_id' integer PRIMARY KEY AUTOINCREMENT, 'title_link', 'sent_orig')")

# %% [markdown]
# таблица энграмм

# %%
cur.execute("CREATE TABLE IF NOT EXISTS 'Corpus'('ngr_id' integer PRIMARY KEY AUTOINCREMENT, '3-gram0_orig', '3-gram1_orig', '3-gram2_orig', '3-gram0_lem', '3-gram1_lem', '3-gram2_lem', '3-gram0_pos', '3-gram1_pos', '3-gram2_pos', 'sent' integer, FOREIGN KEY('sent') REFERENCES 'Sentences'('sent_id'))")

# %%
conn.commit()
conn.close()

# %% [markdown]
# из словаря big_dict все записывается в бд

# %%
conn = sqlite3.connect('project_db.db')
c = conn.cursor()

# %%
countt = 0 # счетчик для энграмм
for gr in big_dict:
    for i in range(len(big_dict[gr]['sent_id'])):
        sent_id = big_dict[gr]['sent_id'][i]
            
        title_link = big_dict[gr]['text_meta'][i]
        sent_orig = big_dict[gr]['sent_text'][i]
        ngr_id = big_dict[gr]['tag_ngr'][i]
        
        ws = ngr_id.split('> ')
        
        # могут быть не только триграммы, но и биграммы, униграммы (теоретически - если предложение состояло из 1-2 слов)
        
        n_gram1_orig, n_gram1_lem, n_gram1_pos = '', '', ''
        n_gram2_orig, n_gram2_lem, n_gram2_pos = '', '', ''
        
        for j in range(len(ws)):
            w_text = re.search('([^<>]+)<', ws[j]).group(1)
            pos = re.search('<pos:([^>]+)>', ws[j]).group(1)
            lem = re.search('<lem:([^>]+)>?', ws[j]).group(1)
            if j == 0:
                n_gram0_orig = w_text
                n_gram0_lem = lem
                n_gram0_pos = pos
            elif j == 1:
                n_gram1_orig = w_text
                n_gram1_lem = lem
                n_gram1_pos = pos
            else:
                n_gram2_orig = w_text
                n_gram2_lem = lem
                n_gram2_pos = pos
        
        c.execute('INSERT OR IGNORE INTO "Sentences" VALUES (?, ?, ?)', (sent_id, title_link, sent_orig)) 
        # если попробует добавить с повт праймари ки, то проигнорит
        c.execute('INSERT INTO "Corpus" VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)', (countt, n_gram0_orig, n_gram1_orig, n_gram2_orig, n_gram0_lem, n_gram1_lem, n_gram2_lem, n_gram0_pos, n_gram1_pos, n_gram2_pos, sent_id))
        conn.commit()
        countt += 1

# %%
conn.commit()
conn.close()

# %% [markdown]
# ### указать какой набор тегов / стандарт разметки вы используете. Иногда достаточно ссылки на библиотеку (например, тегсет Mystem)

# %% [markdown]
# ### функция для поиска
#
# поиск - нужно найти все предложения, где слово встречается в любой форме
# “поиска” - нужно найти предложения только с этой формой
# знать+NOUN - нужно найти все предложения, где встречается существительное “знать”
# NOUN - найти все предложения с существительными
#
# В питоне это, скорее всего, будет выглядеть так:
# search(‘поиск’)
# search(‘“поиск”’) - дублируем кавычки
# search(‘знать+NOUN’)
# search(‘NOUN VERB ADVB’)
# search(‘ADJ дом’)
#
# Запрос состоит из последовательных слов/POS-тегов (n-грамма,  максимум 3-грамма), к каждому применяются правила выше.

# %% [raw]
# Запросы могут состоять из
#
# 1) леммы/словоформы (тогда нужно найти вхождения во всех формах),
#
# 2) словоформы/фразы в двойных кавычках (тогда нужно найти только заданную форму),
#
# 3) леммы и POS-тега (тогда нужно найти все формы, отмеченные данным тегом).
#
# Выдача должна состоять из предложений с мета-информацией (например, URL страницы, откуда взят текст, или название текста + название источника - например, “Война и мир” - lib.ru)

# %%
list_of_pos = set(['ADJ',
'ADV',
'DET',
'AUX',
'CONJ',
'VERB',
'INTJ',
'NOUN',
'PRON',
'NUM',
'PRCL',
'PART',
'ADP']) # тег 'PUNCT' будет считаться словом

# %%
def generate_request(input_s):
    res_words = []
    
    words = input_s.split(' ') # кошек "нет" NOUN
    for w_index, word in enumerate(words):
        if word[0] == '"':
            if word[-1] != '"': # если кавычка не закрыта
                res_words = []
                print('Попробуйте закрыть двойные кавычки')
                return res_words
            
            #поиск по форме слова
            line = "Corpus.'3-gram@_orig' = " + "'" + word.strip('"') + "'"
        elif word in list_of_pos:
            #поиск по POS
            line = "Corpus.'3-gram@_pos' = " + "'" + word + "'"
        elif '+' in word:
            if word[0] == '+' or word[-1] == '+': # проверкa 'кошка+', 'noun' or '+кошка', 'noun' or '+'
                res_words = []
                print('знак + соединяет лемму/словоформу и часть речи. напр.: ехать+NOUN')
                return res_words
            
            #поиск по POS и леммам. если плюс в середине чего-то напр bbb+aaa
            lemma, POS = word.split('+')
            
            # проверка на то что pos это pos
            if POS not in list_of_pos:
                res_words = []
                print('знак + соединяет лемму/словоформу и часть речи. напр.: ехать+NOUN')
                return res_words
        
            # проверка на то что lemma это лемма # кошкой+NOUN
            # лемматизируем наташей
            lem = get_lem(word)
                
            line = "Corpus.'3-gram@_lem' = " + "'" + lem + "'" + " AND Corpus.'3-gram@_pos' = " + POS
            
        else:
            lem = get_lem(word)
            #поиск по леммам
            line = "Corpus.'3-gram@_lem' = " + "'" + lem + "'"
        
        res_words.append(line)

    return res_words

# %%
# lemmatization
def get_lem(word): # на вход одно слово
    doc = Doc(word)
    doc.segment(segmenter)
    doc.tag_morph(morph_tagger)   
    doc.tokens[0].lemmatize(morph_vocab) 
    # если сегментер разделит по дефису то возьмется лемма 1й половины
    lem = doc.tokens[0].lemma
    
    return lem

# %%
# норм запрос
generate_request('кошек "нет" NOUN')
# Out:
# ["Corpus.'3-gram@_lem' = 'кошка'",
#  "Corpus.'3-gram@_orig' = 'нет'",
#  "Corpus.'3-gram@_pos' = 'NOUN'"]

# %%
# не норм запрос
generate_request('коше+к "нет" NOUN')
# Out:
# знак + соединяет лемму/словоформу и часть речи. напр.: ехать+NOUN
# []

# %%
# ок запрос
generate_request('кошек "не+т" NOUN')
# Out:
# ["Corpus.'3-gram@_lem' = 'кошка'",
#  "Corpus.'3-gram@_orig' = 'не+т'",
#  "Corpus.'3-gram@_pos' = 'NOUN'"]

# %%
# незакрытые кавычки
generate_request('кошек "нет NOUN')
# Out:
# Попробуйте закрыть двойные кавычки
# []

# %%
import re

# %%
def search(input_s):
    input_s = re.sub('\s+', ' ', input_s).strip() # замена повт пробелов на один
    check = len(input_s.split(' '))
    if check > 3 or check < 1:
        return 'Запрос некорректен'
    
    words = generate_request(input_s)
    if words == []:
        return 'Запрос некорректен'
        
    if check == 1:
        request = one_word_requests(words)
        print_scentences(request)
    elif check == 2:
        request = two_words_requests(words)
        print_scentences(request)
    elif check == 3:
        request = three_words_requests(words)
        print_scentences(request)

# %%
def extract_sents_id(case, c): # на вход id sents
    for el in case:
        req = "SELECT sent_orig, title_link FROM Sentences WHERE Sentences.'sent_id' = " + str(el[0])
        sent_orig, title_link = c.execute(req).fetchone()
        print('SENT: ' + sent_orig + '\n' + 'TITLE+URL: ' + title_link)
        print()

# %%
def print_scentences(request):
    conn = sqlite3.connect('project_db.db')
    c = conn.cursor()
    case = c.execute(request).fetchall()
    if case == []:
        print('По вашему запросу было найдено НИЧЕГО')
    else:
        extract_sents_id(case, c)
    c.close()
    conn.close()

# %%
def one_word_requests(words): # на вход list, ключи индексы 0, 1 или 2
    one_w_req = words[0]
    requests = []
    for index in range(3):
        ending = re.sub('@', str(index), one_w_req)
        requests.append(ending)
    res = 'SELECT DISTINCT sent FROM Corpus WHERE ' + ' OR '.join(requests) 
    # distinct чтобы без повторов
    
    return res # возвращает 1 запрос

# %% [markdown]
# пример получаемого запроса в базу

# %%
one_word_requests(generate_request('кошек'))
# Out:
# "SELECT DISTINCT sent FROM Corpus WHERE Corpus.'3-gram0_lem' = 'кошка' OR Corpus.'3-gram1_lem' = 'кошка' OR Corpus.'3-gram2_lem' = 'кошка'"

# %%
def two_words_requests(words):
    requests = []
    indexes = [[0, 1], [1, 2]]
    for pair in indexes:
#         beginning = 'SELECT DISTINCT sent FROM Corpus WHERE '
        middle = re.sub('@', str(pair[0]), words[0])
        conj = ' AND '
        ending = re.sub('@', str(pair[1]), words[1])
        requests.append('(' + middle + conj + ending + ')')
    
    res = 'SELECT DISTINCT sent FROM Corpus WHERE ' + ' OR '.join(requests) 
    return res

# %% [markdown]
# пример получаемого запроса в базу

# %%
two_words_requests(generate_request('кошек NOUN'))
# Out:
# "SELECT DISTINCT sent FROM Corpus WHERE (Corpus.'3-gram0_lem' = 'кошка' AND Corpus.'3-gram1_pos' = 'NOUN') OR (Corpus.'3-gram1_lem' = 'кошка' AND Corpus.'3-gram2_pos' = 'NOUN')"

# %%
def three_words_requests(words):
#     requests = []
#     indexes = [0, 1, 2]
    beginning = 'SELECT DISTINCT sent FROM Corpus WHERE '
    middle_first = re.sub('@', '0', words[0])
    middle_second = re.sub('@', '1', words[1])
    conj = ' AND '
    ending = re.sub('@', '2', words[2])
    res = beginning + middle_first + conj + middle_second + conj + ending
    
    return res

# %% [markdown]
# пример получаемого запроса в базу

# %%
three_words_requests(generate_request('кошек NOUN поить+VERB'))
# Out:
# "SELECT DISTINCT sent FROM Corpus WHERE Corpus.'3-gram0_lem' = 'кошка' AND Corpus.'3-gram1_pos' = 'NOUN' AND Corpus.'3-gram2_lem' = 'поить' AND Corpus.'3-gram2_pos' = VERB"

# %% [markdown]
# # запуск!!!!!!!!!!!!!!!

# %% [markdown]
# ### примеры запросов
# Приведите примеры запросов, которые можно задавать к вашему корпусу.
#
# (Ещё можно описать тематику, чтобы проверяющий мог придумать свои запросы)

# %%
search('"как дела"')
# Out:
# Попробуйте закрыть двойные кавычки
# 'Запрос некорректен'

# %%
search('"Партия"')
# Out:
# SENT: Партия зеленых предложила ввести ограничение скорости 130 км/ч на немецких автобанах, с целью сократить количество выхлопных газов.
# TITLE+URL: Ограничениям скорости на немецких автобанах не бывать!
# https://liveberlin.ru/news/2019/11/04/ogranicheniyam-skorosti-na-nemetskih-avtobanah-ne-byvat/
#
# SENT: По опросам, в Британии лидирует созданная в начале апреля этого года «Партия Brexit», занимающая крайне жесткую позицию в поддержку выхода страны из союза.
# TITLE+URL: Великобритания примет участие в выборах в Европарламент несмотря на Brexit
# https://liveberlin.ru/news/2019/05/09/velikobritaniya-primet-uchastie-v-vyborah-v-evroparlament-nesmotrya-na-brexit/
#
# SENT: Партия этих рыбешек прибыла в начале марта из Гамбурга, куда они в свою очередь были доставлены с Атлантического побережья Франции, сообщает Berliner Morgenpost.
# TITLE+URL: Экология: В берлинские реки выпустят два миллиона угрей
# https://liveberlin.ru/news/2019/03/19/ekologiya-v-berlinskie-reki-vypustyat-dva-milliona-ugrej/

# %%
search('"Партия" VERB ADV')
# Out:
# По вашему запросу было найдено НИЧЕГО

# %% [markdown]
# ### бонусы

# %% [markdown]
# Бонус - если вы придумали какие-то оптимизации, чтобы поиск работал быстрее, не забудьте сказать о них :)
#
# Ещё бонус - разбор ошибок, которые делает функция поиска

# %% [markdown]
# ### Если jupyter-тетрадка, то можно ссылку на гитхаб.
